# %% [markdown]
# ## Finding sum of all numbers in a string

# %%
import re
st = '1abc2x30yz67'
digit_list = re.findall(r'\d+', st)
ans = sum([int(digit) for digit in digit_list])  
print(f'Sum is {ans}')
# Out:
# Sum is 100
